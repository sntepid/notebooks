# %% [markdown]
# # Thème 5 : Cartographie, Géolocalisation
# ---
# ## TP2 : Cartes avec Python

# %% [markdown]
# ---
# Nous allons utiliser les cartes proposées par Open Street Map et le langage Python afin de générer des cartes personnalisées. Plus exactement, nous allons utiliser une bibliothèque Python nommée Folium.
# ### Question 1 <i class="fa fa-cog fa-spin fa-3x fa-fw"></i>
# <span class="sr-only">Loading...</span> Recopier chaque ligne dans la cellule Python ci-dessous et l'exécuter.
# ![image.png](attachment:image.png)

# %% [markdown]
# Nous sauvegardons la carte générée dans un fichier html (maCarte1.html)
# Ce fichier est stocké dans votre répertoire. Vérifier que le fichier est présent :
# ![image.png](attachment:image.png)

# %% [markdown]
# Ouvrir ce fichier html.
# ### Question 2 <i class="fa fa-cog fa-spin fa-3x fa-fw"></i>
# <span class="sr-only">Loading...</span> En quel lieu sommes-nous ?

# %% [markdown]
# Lieu : *double-cliquer ici pour répondre*.

# %% [markdown]
# ### Question 3 <i class="fa fa-cog fa-spin fa-3x fa-fw"></i>
# <span class="sr-only">Loading...</span> Modifier le programme pour qu'il génère une carte centrée sur la ville de votre choix.

# %% [markdown]
# ### Question 4 <i class="fa fa-cog fa-spin fa-3x fa-fw"></i>
# <span class="sr-only">Loading...</span> Modifiez le programme en ajoutant à la méthode `Map` le paramètre `zoom_start` afin d’effectuer un zoom sur votre carte.

# %% [markdown]
# ### Question 5 <i class="fa fa-cog fa-spin fa-3x fa-fw"></i>
# <span class="sr-only">Loading...</span> Recopier ce code dans la cellule ci-dessous et expliquer ce qu'il fait sur la carte :
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# ## Petit problème à résoudre
# Pendant le confinement, M. Jouin (qui vit au lycée EPID), M. Buniet (qui vit au Camping Zuydcoote Beach) et M. Pecourt (qui vit à l'Église catholique Saint-Martin à Bergues) veulent savoir jusqu'où ils peuvent aller faire du roller.
# Dans ce confinement on ne pas quitter la zone située dans un rayon de 5km autour du domicile.
# L’objectif est de créer une zone (*cercle*) autour de la position des trois merveilleux, fabuleux, extraordinaires et légendaires professeurs de SNT.
#
# Vous utiliserez cette fonction :
# `folium.Circle(location=[LAT, LONG], radius= ??).add_to(c)` où :
#    - *LAT* ET *LONG* sont à remplacer par les coordonnées !
#    - *??* est à remplacer aussi !
#
# *Vous pouvez aussi ajouter des marqueurs (`Marker` de la question 5) pour cibler les domiciles des 3 professeurs.*

# %%
# Importer folium

# Variables pour les coordonnées

# Créer la carte

# Créer les repères

# Créer les cercles

# Enregistrer en HTML

# %% [markdown]
# [zone_confinement.html](zone_confinement.html)

# %% [markdown]
# ### Question 6 <i class="fa fa-cog fa-spin fa-3x fa-fw"></i>
# <span class="sr-only">Loading...</span> Peuvent-ils aller jusqu'à La Panne en Belgique ? Au fort de Petite Synthe ?

# %% [markdown]
# ### Question 7 <i class="fa fa-cog fa-spin fa-3x fa-fw"></i>
# <span class="sr-only">Loading...</span> Pourront-ils se rencontrer ? Si oui, où et qui ?
